# %%
# !pip install pandas pyarrow fastparquet
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: pyarrow in /opt/anaconda3/lib/python3.12/site-packages (16.1.0)
# Requirement already satisfied: fastparquet in /opt/anaconda3/lib/python3.12/site-packages (2024.11.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: cramjam>=2.3 in /opt/anaconda3/lib/python3.12/site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from fastparquet) (24.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
df = pd.read_parquet("samples_3k_project_c_updated.parquet")
print(df)
# Out:
#       label                                id  \
# 0       1.0  08f391ab10c7114d033517ea0e3905a9
# 1       0.0  08f26ed44c0f20f103c3e3cc6e5bed37
# 2       0.0  08f2a100d649b2940358781f0b0c6078
# 3       0.0  08f266886ad2b15c0330a29679895fc5
# 4       1.0  08f8010646c29a5503b6cc2ed88f8859
# ...     ...                               ...
# 2995    0.0  08f1fb475062a86a038caa03f709bc39
# 2996    0.0  08f445c04592a7a803d95896dfd5150b
# 2997    1.0  08f1e884cc665729030f75c5b49b8ec8
# 2998    1.0  08fa81955b34a9b303580e4545ded3f2
# 2999    1.0  08f480aa6da050920338531a418d7478
#
#                                base_id  \
# 0                      562949956772225
# 1                     1407374886409435
# 2     08f2a10725b1451a03d80f18dbf3f667
# 3     08f266886ad2b15c034a5726e85dc631
# 4     08f8010646c66a2903260dd893bdb585
# ...                                ...
# 2995          4cb581079c7ba35d4bc18a06
# 2996          4c4dc30fea24c9b623019c14
# 2997          7ed4b8a66f2e41f14d2b45f2
# 2998          51ed2f0b498e8e7bde84b219
# 2999          5033eddfe4b055d9f3db9b3e
#
#                                                 sources  \
# 0     [{"property":"","dataset":"meta","record_id":"...
# 1     [{"property":"","dataset":"meta","record_id":"...
# 2     [{"property":"","dataset":"meta","record_id":"...
# 3     [{"property":"","dataset":"msft","record_id":"...
# 4     [{"property":"","dataset":"meta","record_id":"...
# ...                                                 ...
# 2995  [{"property":"","dataset":"meta","record_id":"...
# 2996  [{"property":"","dataset":"Microsoft","record_...
# 2997  [{"property":"","dataset":"meta","record_id":"...
# 2998  [{"property":"","dataset":"meta","record_id":"...
# 2999  [{"property":"","dataset":"meta","record_id":"...
#
#                                                   names  \
# 0                                      {"primary":"BP"}
# 1                {"primary":"Northwest Medical Center"}
# 2         {"primary":"Manhattan Hardware & Housewares"}
# 3     {"primary":"UofL Physicians – Plastic & Recons...
# 4                        {"primary":"Pousada da Taiba"}
# ...                                                 ...
# 2995                       {"primary":"Bâtiment STAPS"}
# 2996                               {"primary":"Subway"}
# 2997                             {"primary":"Suite 61"}
# 2998                      {"primary":"UBS Vila Elvira"}
# 2999                  {"primary":"Pollo Feliz Obregón"}
#
#                                              categories  confidence  \
# 0     {"primary":"gas_station","alternate":["energy_...    0.996261
# 1     {"primary":"hospital","alternate":["health_and...    0.997899
# 2     {"primary":"hardware_store","alternate":["home...    0.964513
# 3     {"primary":"plastic_surgeon","alternate":["doc...    0.770000
# 4     {"primary":"hotel","alternate":["active_life",...    0.792793
# ...                                                 ...         ...
# 2995  {"primary":"stadium_arena","alternate":["footb...    0.394150
# 2996  {"primary":"fast_food_restaurant","alternate":...    0.770000
# 2997  {"primary":"bed_and_breakfast","alternate":["h...    0.964513
# 2998  {"primary":"health_and_medical","alternate":["...    0.481039
# 2999  {"primary":"chicken_restaurant","alternate":["...    0.286713
#
#                                                websites  \
# 0     ["https://map.bp.com/es-ES/ES/estacion-de-serv...
# 1                   ["http://www.northwesthealth.com/"]
# 2             ["https://twitter.com/#!/9thAveHardware"]
# 3     ["https://uoflhealth.org/locations/ulp-plastic...
# 4                     ["http://pousadadataiba.com.br/"]
# ...                                                 ...
# 2995                                               None
# 2996  ["https://restaurants.subway.com/united-states...
# 2997  ["https://www.booking.com/hotel/it/suite61.it....
# 2998                                               None
# 2999                                               None
#
#                                             socials emails  ...  \
# 0      ["https://www.facebook.com/112012623717552"]   None  ...
# 1      ["https://www.facebook.com/680873018646122"]   None  ...
# 2      ["https://www.facebook.com/259327777460966"]   None  ...
# 3                                              None   None  ...
# 4      ["https://www.facebook.com/170546886327152"]   None  ...
# ...                                             ...    ...  ...
# 2995   ["https://www.facebook.com/327324387852427"]   None  ...
# 2996                                           None   None  ...
# 2997  ["https://www.facebook.com/2213733138867454"]   None  ...
# 2998   ["https://www.facebook.com/936203839837757"]   None  ...
# 2999  ["https://www.facebook.com/2140888489558296"]   None  ...
#
#                                            base_sources  \
# 0     [{"dataset":"Microsoft","record_id":"562949956...
# 1     [{"dataset":"Microsoft","record_id":"140737488...
# 2     [{"property":"","dataset":"meta","record_id":"...
# 3     [{"property":"","dataset":"msft","record_id":"...
# 4     [{"property":"","dataset":"meta","record_id":"...
# ...                                                 ...
# 2995  [{"property":"","dataset":"FourSquare","record...
# 2996  [{"property":"","dataset":"FourSquare","record...
# 2997  [{"property":"","dataset":"FourSquare","record...
# 2998  [{"property":"","dataset":"FourSquare","record...
# 2999  [{"property":"","dataset":"FourSquare","record...
#
#                                              base_names  \
# 0                                      {"primary":"BP"}
# 1     {"primary":"Northwest Medical Center - Emergen...
# 2                          {"primary":"Manhattan Jazz"}
# 3             {"primary":"UofL Physicians – Neurology"}
# 4                       {"primary":"Pousada Taiba Inn"}
# ...                                                 ...
# 2995    {"primary":"Bâtiment G","common":{},"rules":[]}
# 2996        {"primary":"Subway","common":{},"rules":[]}
# 2997      {"primary":"Suite 61","common":{},"rules":[]}
# 2998  {"primary":"UBS Vila Elvira - São José Do Rio ...
# 2999   {"primary":"Pollo Feliz","common":{},"rules":[]}
#
#                                         base_categories base_confidence  \
# 0     {"primary":"car_wash","alternate":["ev_chargin...        0.770000
# 1     {"primary":"emergency_room","alternate":["heal...        0.770000
# 2     {"primary":"dance_club","alternate":["jazz_and...        0.286713
# 3                      {"primary":"health_and_medical"}        0.770000
# 4                                   {"primary":"hotel"}        0.394150
# ...                                                 ...             ...
# 2995  {"primary":"Community and Government > Educati...        1.000000
# 2996  {"primary":"Dining and Drinking > Restaurant >...        1.000000
# 2997                                                 {}        1.000000
# 2998  {"primary":"Health and Medicine > Emergency Se...        1.000000
# 2999  {"primary":"Dining and Drinking > Restaurant >...        1.000000
#
#                                           base_websites  \
# 0     ["https://www.bp.com/es_es/on-the-road/spain.h...
# 1     ["https://www.northwesthealth.com/emergency-de...
# 2                                                  None
# 3     ["https://uoflhealth.org/locations/neurology-4...
# 4                 ["http://www.pousadataibainn.com.br"]
# ...                                                 ...
# 2995                                             [null]
# 2996  ["https://restaurants.subway.com/united-states...
# 2997                                             [null]
# 2998                                             [null]
# 2999             ["http://www.pollofelizqueretaro.com"]
#
#                                        base_socials  base_emails  \
# 0                                              None         None
# 1                                              None         None
# 2      ["https://www.facebook.com/116155878405321"]         None
# 3                                              None         None
# 4     ["https://www.facebook.com/1913210835595304"]         None
# ...                                             ...          ...
# 2995                               [null,null,null]       [null]
# 2996   ["https://www.twitter.com/subway",null,null]       [null]
# 2997                               [null,null,null]       [null]
# 2998                               [null,null,null]       [null]
# 2999                               [null,null,null]       [null]
#
#              base_phones                                         base_brand  \
# 0          ["956621050"]                                       {"names":{}}
# 1         ["4797571000"]                                       {"names":{}}
# 2       ["+12125814269"]                                               None
# 3         ["5025884800"]                                               None
# 4       ["+18533156140"]                                               None
# ...                  ...                                                ...
# 2995              [null]  {"wikidata":"","names":{"primary":"Bâtiment G"...
# 2996  ["(601) 360-2831"]  {"wikidata":"","names":{"primary":"Subway","co...
# 2997    ["392 377 4184"]  {"wikidata":"","names":{"primary":"Suite 61","...
# 2998              [null]  {"wikidata":"","names":{"primary":"UBS Vila El...
# 2999              [null]  {"wikidata":"","names":{"primary":"Pollo Feliz...
#
#                                          base_addresses
# 0     [{"freeform":"Av. Carlos Cano, Glorieta La Mon...
# 1     [{"freeform":"609 W Maple Ave","locality":"Spr...
# 2     [{"freeform":"445 W 45th St","locality":"New Y...
# 3     [{"freeform":"401 E Chestnut St Unit 510","loc...
# 4     [{"freeform":"Rua Capitão Inácio Prata, S/N","...
# ...                                                 ...
# 2995  [{"freeform":"Université Paris Ouest Nanterre ...
# 2996  [{"freeform":"308 E Pearl St Ste 101","localit...
# 2997  [{"freeform":"Claustro Crocifisso 61","localit...
# 2998                                 [{"country":"BR"}]
# 2999  [{"freeform":"Tabasco e Hidalgo","locality":"C...
#
# [3000 rows x 23 columns]

# %%
import pandas as pd
import json

# Load your parquet file
df = pd.read_parquet("samples_3k_project_c_updated.parquet")

# Check dimensions and columns
print(df.shape)
df.info()

# Peek at first few rows
pd.set_option('display.max_colwidth', 120)
display(df.head(3))
# Out:
# (3000, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   label            3000 non-null   float64
#  1   id               3000 non-null   object
#  2   base_id          3000 non-null   object
#  3   sources          3000 non-null   object
#  4   names            3000 non-null   object
#  5   categories       2957 non-null   object
#  6   confidence       3000 non-null   float64
#  7   websites         2459 non-null   object
#  8   socials          2090 non-null   object
#  9   emails           0 non-null      object
#  10  phones           2765 non-null   object
#  11  brand            884 non-null    object
#  12  addresses        3000 non-null   object
#  13  base_sources     3000 non-null   object
#  14  base_names       3000 non-null   object
#  15  base_categories  2960 non-null   object
#  16  base_confidence  3000 non-null   float64
#  17  base_websites    2912 non-null   object
#  18  base_socials     1742 non-null   object
#  19  base_emails      1500 non-null   object
#  20  base_phones      2966 non-null   object
#  21  base_brand       2685 non-null   object
#  22  base_addresses   3000 non-null   object
# dtypes: float64(3), object(20)
# memory usage: 539.2+ KB
#    label                                id                           base_id  \
# 0    1.0  08f391ab10c7114d033517ea0e3905a9                   562949956772225
# 1    0.0  08f26ed44c0f20f103c3e3cc6e5bed37                  1407374886409435
# 2    0.0  08f2a100d649b2940358781f0b0c6078  08f2a10725b1451a03d80f18dbf3f667
#
#                                                                                                                    sources  \
# 0  [{"property":"","dataset":"meta","record_id":"112012623717552","update_time":"2025-01-06T00:00:00.000Z"},{"property"...
# 1  [{"property":"","dataset":"meta","record_id":"680873018646122","update_time":"2025-01-06T00:00:00.000Z"},{"property"...
# 2                [{"property":"","dataset":"meta","record_id":"259327777460966","update_time":"2025-01-06T00:00:00.000Z"}]
#
#                                            names  \
# 0                               {"primary":"BP"}
# 1         {"primary":"Northwest Medical Center"}
# 2  {"primary":"Manhattan Hardware & Housewares"}
#
#                                                                                   categories  \
# 0                             {"primary":"gas_station","alternate":["energy_company","bar"]}
# 1  {"primary":"hospital","alternate":["health_and_medical","medical_service_organizations"]}
# 2             {"primary":"hardware_store","alternate":["home_improvement_store","shopping"]}
#
#    confidence  \
# 0    0.996261
# 1    0.997899
# 2    0.964513
#
#                                                                                         websites  \
# 0  ["https://map.bp.com/es-ES/ES/estacion-de-servicio/los-barrios/e-s-bp-la-montera/1023746243"]
# 1                                                            ["http://www.northwesthealth.com/"]
# 2                                                      ["https://twitter.com/#!/9thAveHardware"]
#
#                                         socials emails  ...  \
# 0  ["https://www.facebook.com/112012623717552"]   None  ...
# 1  ["https://www.facebook.com/680873018646122"]   None  ...
# 2  ["https://www.facebook.com/259327777460966"]   None  ...
#
#                                                                                                          base_sources  \
# 0    [{"dataset":"Microsoft","record_id":"562949956772225","update_time":"2020-02-06T19:40:35.69","confidence":0.77}]
# 1  [{"dataset":"Microsoft","record_id":"1407374886409435","update_time":"2023-10-16T12:58:08.957","confidence":0.77}]
# 2           [{"property":"","dataset":"meta","record_id":"116155878405321","update_time":"2025-01-06T00:00:00.000Z"}]
#
#                                                 base_names  \
# 0                                         {"primary":"BP"}
# 1  {"primary":"Northwest Medical Center - Emergency Room"}
# 2                             {"primary":"Manhattan Jazz"}
#
#                                                                          base_categories  \
# 0  {"primary":"car_wash","alternate":["ev_charging_station","gas_station","automotive"]}
# 1                        {"primary":"emergency_room","alternate":["health_and_medical"]}
# 2       {"primary":"dance_club","alternate":["jazz_and_blues","arts_and_entertainment"]}
#
#   base_confidence  \
# 0        0.770000
# 1        0.770000
# 2        0.286713
#
#                                                                                                             base_websites  \
# 0                                                                     ["https://www.bp.com/es_es/on-the-road/spain.html"]
# 1  ["https://www.northwesthealth.com/emergency-department?utm_source=Bing&utm_campaign=biz-listings&utm_medium=homepage"]
# 2                                                                                                                    None
#
#                                    base_socials  base_emails  \
# 0                                          None         None
# 1                                          None         None
# 2  ["https://www.facebook.com/116155878405321"]         None
#
#         base_phones    base_brand  \
# 0     ["956621050"]  {"names":{}}
# 1    ["4797571000"]  {"names":{}}
# 2  ["+12125814269"]          None
#
#                                                                                                             base_addresses
# 0  [{"freeform":"Av. Carlos Cano, Glorieta La Montera","locality":"Los Barrios","region":"Cádiz","country":"ES","postco...
# 1                 [{"freeform":"609 W Maple Ave","locality":"Springdale","region":"AR","country":"US","postcode":"72764"}]
# 2                [{"freeform":"445 W 45th St","locality":"New York","postcode":"10036-3502","region":"NY","country":"US"}]
#
# [3 rows x 23 columns]

# %%
def safe_json(x):
    if isinstance(x, (dict, list)):
        return x
    if pd.isna(x):
        return {}
    try:
        return json.loads(x)
    except Exception:
        return {}

json_cols = [
    "names", "categories", "addresses", "websites", "socials", "emails", "phones",
    "base_names", "base_categories", "base_addresses", "base_websites", "base_socials",
    "base_emails", "base_phones"
]

for c in json_cols:
    if c in df.columns:
        df[c] = df[c].apply(safe_json)

# %%
def get_primary_name(d):
    if isinstance(d, dict):
        return d.get("primary", "")
    return ""

def get_address_text(addr):
    if not addr:
        return ""
    if isinstance(addr, list):
        addr = addr[0] if len(addr) > 0 else {}
    return " | ".join(str(addr.get(k, "")) for k in ["freeform", "locality", "region", "country"] if addr.get(k))

# Left side
df["name"] = df["names"].apply(get_primary_name)
df["address"] = df["addresses"].apply(get_address_text)
df["website"] = df["websites"].apply(lambda x: x[0] if isinstance(x, list) and len(x)>0 else "")
df["phone"] = df["phones"].apply(lambda x: x[0] if isinstance(x, list) and len(x)>0 else "")

# Base side
df["base_name"] = df["base_names"].apply(get_primary_name)
df["base_address"] = df["base_addresses"].apply(get_address_text)
df["base_website"] = df["base_websites"].apply(lambda x: x[0] if isinstance(x, list) and len(x)>0 else "")
df["base_phone"] = df["base_phones"].apply(lambda x: x[0] if isinstance(x, list) and len(x)>0 else "")

# %%
def normalize_text(s):
    if not isinstance(s, str):
        return ""
    return " ".join(s.lower().strip().split())

cols_to_clean = ["name", "address", "website", "phone", "base_name", "base_address", "base_website", "base_phone"]
for c in cols_to_clean:
    df[c] = df[c].apply(normalize_text)

df = df.dropna(subset=["name", "base_name"])
print("Cleaned shape:", df.shape)
# Out:
# Cleaned shape: (3000, 31)

# %%
pair_keys = df.apply(lambda r: tuple(sorted([r["name"], r["base_name"]])), axis=1)
df = df.loc[~pair_keys.duplicated()].copy()

print("after cleaning:", df.shape)
# Out:
# after cleaning: (2731, 31)

# %%
df_clean = df[[
    "id", "base_id",
    "name", "address", "website", "phone",
    "base_name", "base_address", "base_website", "base_phone",
    "confidence", "base_confidence"
]]

df_clean.to_parquet("places_cleaned.parquet", index=False)
df_clean.head()
# Out:
#                                  id                           base_id  \
# 0  08f391ab10c7114d033517ea0e3905a9                   562949956772225
# 1  08f26ed44c0f20f103c3e3cc6e5bed37                  1407374886409435
# 2  08f2a100d649b2940358781f0b0c6078  08f2a10725b1451a03d80f18dbf3f667
# 3  08f266886ad2b15c0330a29679895fc5  08f266886ad2b15c034a5726e85dc631
# 4  08f8010646c29a5503b6cc2ed88f8859  08f8010646c66a2903260dd893bdb585
#
#                                                  name  \
# 0                                                  bp
# 1                            northwest medical center
# 2                     manhattan hardware & housewares
# 3  uofl physicians – plastic & reconstructive surgery
# 4                                    pousada da taiba
#
#                                                                 address  \
# 0                                avenida carlos cano | los barrios | es
# 1                                609 w maple ave | springdale | ar | us
# 2                                      688 9th ave | new york | ny | us
# 3                     401 e chestnut st unit 790 | louisville | ky | us
# 4  avenida capitão inácio prata, sn | são gonçalo do amarante | ce | br
#
#                                                                                      website  \
# 0  https://map.bp.com/es-es/es/estacion-de-servicio/los-barrios/e-s-bp-la-montera/1023746243
# 1                                                            http://www.northwesthealth.com/
# 2                                                      https://twitter.com/#!/9thavehardware
# 3                                      https://uoflhealth.org/locations/ulp-plastic-surgery/
# 4                                                              http://pousadadataiba.com.br/
#
#           phone                                  base_name  \
# 0  +34956621050                                         bp
# 1  +14797515711  northwest medical center - emergency room
# 2  +12127574555                             manhattan jazz
# 3    5025838303                uofl physicians – neurology
# 4                                        pousada taiba inn
#
#                                                       base_address  \
# 0  av. carlos cano, glorieta la montera | los barrios | cádiz | es
# 1                           609 w maple ave | springdale | ar | us
# 2                               445 w 45th st | new york | ny | us
# 3                401 e chestnut st unit 510 | louisville | ky | us
# 4                               rua capitão inácio prata, s/n | br
#
#                                                                                                          base_website  \
# 0                                                                     https://www.bp.com/es_es/on-the-road/spain.html
# 1  https://www.northwesthealth.com/emergency-department?utm_source=bing&utm_campaign=biz-listings&utm_medium=homepage
# 2
# 3                                                       https://uoflhealth.org/locations/neurology-401-e-chestnut-st/
# 4                                                                                   http://www.pousadataibainn.com.br
#
#      base_phone  confidence  base_confidence
# 0     956621050    0.996261         0.770000
# 1    4797571000    0.997899         0.770000
# 2  +12125814269    0.964513         0.286713
# 3    5025884800    0.770000         0.770000
# 4  +18533156140    0.792793         0.394150
